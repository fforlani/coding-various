# %%
filenames = ["00-trailer.txt",
             "01-comedy.txt",
             "02-sentimental.txt",
             "03-adventure.txt",
             "04-drama.txt",
             "05-horror.txt"]
idx = 0
with open(filenames[idx]) as f:
    l = f.readlines()
    if idx == 0: l[0] = l[0][3:]

dims = l[0].split(" ")
dims[-1] = dims[-1][:-1] 

golds = {}
silvs = {}
tiles = {}
X, Y = int(dims[0]), int(dims[1])
G, S, T = int(dims[2]), int(dims[3]), int(dims[4])
X,Y,G,S,T
# Out:
# (10, 7, 3, 4, 11)

# %%
b = "twdfuy\n"
b[:]
# Out:
# 'twdfuy\n'
